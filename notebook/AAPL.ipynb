# %%
import os, sys
import pandas as pd
current_dir = os.getcwd()
parent_dir = os.path.dirname(current_dir)
print(parent_dir)
sys.path.insert(0, parent_dir)
# Out:
# /Users/amantebeje/Desktop/projects/Stock-market-data-analysis-and-prediction

# %%
from scripts.task3_merger import merge
from scripts.logger import SetupLogger
logger = SetupLogger(log_file='../logs/notebooks.log').get_logger()

# %%
stocks='../Data/yfinance_data/AAPL_historical_data.csv'
news='../Data/AAPL.csv'
df_news=pd.read_csv(news)
df_stock=pd.read_csv(stocks)
cor=merge(df_news,df_stock,logger)

# %%
cor.combine()
# Out:
#           date  sentiment_score       Open       High        Low      Close  \
# 0   2020-03-09         0.666667  65.937500  69.522499  65.750000  66.542503
# 1   2020-03-10         0.250000  69.285004  71.610001  67.342499  71.334999
# 2   2020-03-11         0.000000  69.347504  70.305000  67.964996  68.857498
# 3   2020-03-12         0.400000  63.985001  67.500000  62.000000  62.057499
# 4   2020-03-13         0.272727  66.222504  69.980003  63.237499  69.492500
# ..         ...              ...        ...        ...        ...        ...
# 56  2020-05-29         0.000000  79.812500  80.287498  79.117500  79.485001
# 57  2020-06-01         0.666667  79.437500  80.587502  79.302498  80.462502
# 58  2020-06-02         1.000000  80.187500  80.860001  79.732498  80.834999
# 59  2020-06-09         0.000000  83.035004  86.402496  83.002502  85.997498
# 60  2020-06-10         0.000000  86.974998  88.692497  86.522499  88.209999
#
#     Adj Close     Volume  Dividends  Stock Splits
# ...

# %%
cor.final()
# Out:
#           date      Close  sentiment_score  Daily Return  Lagged Sentiment
# 1   2020-03-10  71.334999         0.250000      0.072022          0.666667
# 2   2020-03-11  68.857498         0.000000     -0.034731          0.250000
# 3   2020-03-12  62.057499         0.400000     -0.098755          0.000000
# 4   2020-03-13  69.492500         0.272727      0.119808          0.400000
# 5   2020-03-16  60.552502         0.272727     -0.128647          0.272727
# 6   2020-03-17  63.215000         0.166667      0.043970          0.272727
# 7   2020-03-18  61.667500         0.500000     -0.024480          0.166667
# 8   2020-03-19  61.195000         0.000000     -0.007662          0.500000
# 9   2020-03-20  57.310001         0.000000     -0.063486          0.000000
# 10  2020-03-23  56.092499         0.500000     -0.021244          0.000000
# 11  2020-03-24  61.720001         0.714286      0.100325          0.500000
# ...

# %%
cor.compute_correlation()
# Out:
# Correlation between sentiment score and stock movement: 0.1442
# 0.1442328360839514
