# %%
import os, sys
current_dir = os.getcwd()
parent_dir = os.path.dirname(current_dir)
print(parent_dir)
sys.path.insert(0, parent_dir)
# Out:
# /Users/amantebeje/Desktop/projects/Stock-market-data-analysis-and-prediction

# %%
#Loading data
from scripts.finance import financial_analysis
from scripts.logger import SetupLogger
logger = SetupLogger(log_file='../logs/notebooks.log').get_logger()
analyzer=financial_analysis(logger)
path='../Data/AAPL.csv'
df= analyzer.load_data('AAPL','2011-05-12','2025-01-31',path)
df
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price       Date       Close        High         Low        Open     Volume
# 0     2011-05-12   10.429535   10.446087   10.300134   10.415994  322000000
# 1     2011-05-13   10.246870   10.419908   10.242356   10.402153  326116000
# 2     2011-05-16   10.030196   10.268538   10.009130   10.207749  449775200
# 3     2011-05-17   10.115661   10.115661    9.952854    9.991074  452334400
# 4     2011-05-18   10.227910   10.263420   10.111448   10.125592  334776400
# ...          ...         ...         ...         ...         ...        ...
# 3446  2025-01-24  222.535324  225.382200  221.166834  224.533128   54697900
# 3447  2025-01-27  229.607544  231.895022  223.733997  223.773962   94863400
# 3448  2025-01-28  237.998322  239.926210  230.556507  230.596471   75707600
# 3449  2025-01-29  239.097122  239.596573  233.752992  233.862872   45486100
# ...

# %%
#Checking the existance of specific columns open,close,high and low
result= analyzer.check_existance()
result
# Out:
# True

# %%
#Plotting the graph for 4 columns
analyzer.closing('AAPL')

# %%
analyzer.rolling_avg()

# %%
analyzer.outliers()

# %%
#Technical analysis with TAlib
TA= analyzer.calculate_technical_indicators()
TA
# Out:
# Price       Date       Close        High         Low        Open     Volume  \
# 0     2011-06-30   10.101521   10.115365   10.016356   10.072330  322954800
# 1     2011-07-01   10.329929   10.337151   10.057281   10.109945  435313200
# 2     2011-07-05   10.515604   10.527642   10.307056   10.322102  355054000
# 3     2011-07-06   10.585724   10.656144   10.433751   10.501161  444626000
# 4     2011-07-07   10.749435   10.773510   10.653135   10.673299  399663600
# ...          ...         ...         ...         ...         ...        ...
# 3412  2025-01-24  222.535324  225.382200  221.166834  224.533128   54697900
# 3413  2025-01-27  229.607544  231.895022  223.733997  223.773962   94863400
# 3414  2025-01-28  237.998322  239.926210  230.556507  230.596471   75707600
# 3415  2025-01-29  239.097122  239.596573  233.752992  233.862872   45486100
# 3416  2025-01-30  237.329056  240.525538  236.949483  238.407871   55658300
#
# ...

# %%
#Plotting graphs for SMA, EMA, RSI, MACD and MACD_SIGNAL just change the parameter to see the graphs of different indicators
analyzer.plot_TI('SMA')

# %%
analyzer.decompose()

# %%
# Calculating and Visualizing 3 different finacial meterics like Daily return, Cumilative return and annualized volitilty
analyzer.metrics()
